# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("WHO COVID-19 global table data June 27th 2021 at 4.32.12 PM.csv")

# %%
df
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 179686071
# 1    United States of America         Americas                  33257768
# 2                       India  South-East Asia                  30134445
# 3                      Brazil         Americas                  18169881
# 4                      France           Europe                   5655376
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %%
richard = df.loc[(df['WHO Region'] == 'Africa')]
richard
# Out:
#                                  Name WHO Region  Cases - cumulative total  \
# 19                       South Africa     Africa                   1877143
# 67                           Ethiopia     Africa                    275601
# 81                              Kenya     Africa                    181239
# 83                            Nigeria     Africa                    167401
# 87                             Zambia     Africa                    140620
# 89                            Algeria     Africa                    137403
# 101                             Ghana     Africa                     95259
# 103                           Namibia     Africa                     81270
# 104                          Cameroon     Africa                     80487
# 106                            Uganda     Africa                     75537
# 108                        Mozambique     Africa                     73652
# ...

# %%
richard.head()
# Out:
#             Name WHO Region  Cases - cumulative total  \
# 19  South Africa     Africa                   1877143
# 67      Ethiopia     Africa                    275601
# 81         Kenya     Africa                    181239
# 83       Nigeria     Africa                    167401
# 87        Zambia     Africa                    140620
#
#     Cases - cumulative total per 100000 population  \
# 19                                         3165.04
# 67                                          239.73
# 81                                          337.06
# 83                                           81.21
# 87                                          764.91
#
#     Cases - newly reported in last 7 days  \
# 19                                  91064
# 67                                    826
# 81                                   3957
# 83                                    259
# 87                                  18376
#
# ...

# %%
richard.tail()
# Out:
#                             Name WHO Region  Cases - cumulative total  \
# 181                      Liberia     Africa                      3265
# 189        Sao Tome and Principe     Africa                      2364
# 194                    Mauritius     Africa                      1852
# 203  United Republic of Tanzania     Africa                       509
# 233                 Saint Helena     Africa                         0
#
#      Cases - cumulative total per 100000 population  \
# 181                                           64.56
# 189                                         1078.67
# 194                                          145.62
# 203                                            0.85
# 233                                            0.00
#
#      Cases - newly reported in last 7 days  \
# 181                                    536
# 189                                      5
# 194                                     79
# 203                                      0
# ...

# %%
richard.dtypes
# Out:
# Name                                                             object
# WHO Region                                                       object
# Cases - cumulative total                                          int64
# Cases - cumulative total per 100000 population                  float64
# Cases - newly reported in last 7 days                             int64
# Cases - newly reported in last 7 days per 100000 population     float64
# Cases - newly reported in last 24 hours                           int64
# Deaths - cumulative total                                         int64
# Deaths - cumulative total per 100000 population                 float64
# Deaths - newly reported in last 7 days                            int64
# Deaths - newly reported in last 7 days per 100000 population    float64
# Deaths - newly reported in last 24 hours                          int64
# Transmission Classification                                      object
# dtype: object

# %%
richard.describe()
# Out:
#        Cases - cumulative total  \
# count              5.000000e+01
# mean               7.822606e+04
# std                2.653622e+05
# min                0.000000e+00
# 25%                6.333500e+03
# 50%                1.995850e+04
# 75%                4.712000e+04
# max                1.877143e+06
#
#        Cases - cumulative total per 100000 population  \
# count                                       50.000000
# mean                                      1060.529800
# std                                       2523.380276
# min                                          0.000000
# 25%                                        101.417500
# 50%                                        230.955000
# 75%                                        505.582500
# max                                      15364.980000
#
#        Cases - newly reported in last 7 days  \
# count                              50.000000
# mean                             3215.760000
# ...

# %%
richard.shape
# Out:
# (50, 13)

# %%
richard['WHO Region'].value_counts().to_frame()
# Out:
#         WHO Region
# Africa          50

# %% [markdown]
# # Transmission Classification

# %%
#richard['Transmission Classification'].value_counts().to_frame()

# %%
richard.corr()
# Out:
#                                                     Cases - cumulative total  \
# Cases - cumulative total                                            1.000000
# Cases - cumulative total per 100000 population                      0.105260
# Cases - newly reported in last 7 days                               0.969138
# Cases - newly reported in last 7 days per 10000...                  0.099370
# Cases - newly reported in last 24 hours                             0.947494
# Deaths - cumulative total                                           0.993836
# Deaths - cumulative total per 100000 population                     0.575956
# Deaths - newly reported in last 7 days                              0.933022
# Deaths - newly reported in last 7 days per 1000...                  0.148798
# Deaths - newly reported in last 24 hours                            0.830222
#
#                                                     Cases - cumulative total per 100000 population  \
# ...

# %%
richard[['Cases - newly reported in last 24 hours','Cases - newly reported in last 7 days per 100000 population','Cases - cumulative total per 100000 population']].corr()
# Out:
#                                                     Cases - newly reported in last 24 hours  \
# Cases - newly reported in last 24 hours                                            1.000000
# Cases - newly reported in last 7 days per 10000...                                 0.204192
# Cases - cumulative total per 100000 population                                     0.146628
#
#                                                     Cases - newly reported in last 7 days per 100000 population  \
# Cases - newly reported in last 24 hours                                                      0.204192
# Cases - newly reported in last 7 days per 10000...                                           1.000000
# Cases - cumulative total per 100000 population                                               0.858236
#
#                                                     Cases - cumulative total per 100000 population
# ...

# %%
subsetdata_set = richard [['Name', 'Cases - cumulative total','Deaths - cumulative total']]
subsetdata_set.head()
# Out:
#             Name  Cases - cumulative total  Deaths - cumulative total
# 19  South Africa                   1877143                      59406
# 67      Ethiopia                    275601                       4296
# 81         Kenya                    181239                       3538
# 83       Nigeria                    167401                       2118
# 87        Zambia                    140620                       1855

# %%
subsetdata_set = richard [['Name', 'Cases - newly reported in last 24 hours', 'Transmission Classification']]
subsetdata_set.head()
# Out:
#             Name  Cases - newly reported in last 24 hours  \
# 19  South Africa                                    16078
# 67      Ethiopia                                       99
# 81         Kenya                                      741
# 83       Nigeria                                       70
# 87        Zambia                                     3594
#
#    Transmission Classification
# 19      Community transmission
# 67      Community transmission
# 81      Community transmission
# 83      Community transmission
# 87      Community transmission

# %%
# generate related variables
#data1=cases in last 7days,std=130.211952,mean=4279.780000
#data2=deaths in last 24 hours, std=65.9015,mean =14.8200

from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot
# seed random number generator
seed(1)
# prepare data
data1 = 130.211952 * randn(50) + 4279.780000
data2 = data1 + (65.9015 * randn(50) + 14.8200)
# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
# plot
pyplot.scatter(data1, data2)
pyplot.show()
# Out:
# data1: mean=4276.458 stdv=126.252
# data2: mean=4300.944 stdv=135.293

# %%
np.cov(data1 ,data2)
# Out:
# array([[16264.89395965, 16115.10062214],
#        [16115.10062214, 18677.79939793]])

# %%
# calculate the Pearson's correlation between two variables
from numpy.random import randn
from numpy.random import seed
from scipy.stats import pearsonr
# seed random number generator
seed(1)
# prepare data
data1 = 130.211952 * randn(50) + 4279.780000
data2 = data1 + (65.9015 * randn(50) + 14.8200)
# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)
print('Pearsons correlation: %.3f' % corr)

# %% [markdown]
# Decision making;
# A model with a a high R-squared and low RMSE is the best.
#
# Multiple Linear Regression Model is the best because it has an accuracy (R-Squared) percenatge of approximately 95.48% with a low RSME of approximately 55.40
